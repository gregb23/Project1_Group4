# %%
#set dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import scipy.stats as stats

# %%
#import values and crime data
values_file = os.path.join("../Resources/2019_Hill_Prop_Value.csv")
crime_file = os.path.join("../Resources/combined_crime_data.csv")

value_df = pd.read_csv(values_file,dtype={'NBRHD_CD':'str'} )
crime_df = pd.read_csv(crime_file, dtype={'NBRHD_CD':'str'})

value_df.head()
crime_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Reported Date            Case Number Crime Type  \
# 0         221           324      2/9/2016  2016-94027              BURGLARY
# 1         550           807      4/5/2016  2016-232057                DRUGS
# 2         551           808      4/5/2016  2016-232057                DRUGS
# 3         755          1091      5/7/2016  2016-311881             MISCHIEF
# 4        1836          2540    10/18/2016  2016-728782             MISCHIEF
#
#             Crime Type Extension                Address    zip  year  \
# 0    BURGLARY RESIDENCE / FORCED  14200 BLOCK 12TH ST N  33613  2016
# 1                DRUGS/NARCOTICS  14200 BLOCK 12TH ST N  33613  2016
# 2             DRUG PARAPHERNALIA  14200 BLOCK 12TH ST N  33613  2016
# 3  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613  2016
# 4  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613  2016
#
#   BlockAddress  NBRHD_CD
# 0    N 12TH ST  61400300
# 1    N 12TH ST  61400300
# 2    N 12TH ST  61400300
# 3    N 12TH ST  61400300
# 4    N 12TH ST  61400300

# %%
#drop any null values from crime_df
crime1_df = crime_df.dropna()
crime1_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Reported Date            Case Number Crime Type  \
# 0         221           324      2/9/2016  2016-94027              BURGLARY
# 1         550           807      4/5/2016  2016-232057                DRUGS
# 2         551           808      4/5/2016  2016-232057                DRUGS
# 3         755          1091      5/7/2016  2016-311881             MISCHIEF
# 4        1836          2540    10/18/2016  2016-728782             MISCHIEF
#
#             Crime Type Extension                Address    zip  year  \
# 0    BURGLARY RESIDENCE / FORCED  14200 BLOCK 12TH ST N  33613  2016
# 1                DRUGS/NARCOTICS  14200 BLOCK 12TH ST N  33613  2016
# 2             DRUG PARAPHERNALIA  14200 BLOCK 12TH ST N  33613  2016
# 3  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613  2016
# 4  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613  2016
#
#   BlockAddress  NBRHD_CD
# 0    N 12TH ST  61400300
# 1    N 12TH ST  61400300
# 2    N 12TH ST  61400300
# 3    N 12TH ST  61400300
# 4    N 12TH ST  61400300

# %%
#merge both sheets based on NBRHD_CD
merged_df = value_df.merge(crime1_df, on = 'NBRHD_CD')
merged_df.head()
# Out:
#    Unnamed: 0_x  SEQ_NO               PARCEL_ID  PropertyValue BlockAddress_x  \
# 0         71947   72449  1828010T7000000000290U         118638        12TH ST
# 1         71947   72449  1828010T7000000000290U         118638        12TH ST
# 2         71947   72449  1828010T7000000000290U         118638        12TH ST
# 3         71947   72449  1828010T7000000000290U         118638        12TH ST
# 4         71947   72449  1828010T7000000000290U         118638        12TH ST
#
#    NBRHD_CD     CENSUS_BK    PropAddress   City  ZipCode  ...  Unnamed: 0_y  \
# 0  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...           221
# 1  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...           550
# 2  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...           551
# 3  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...           755
# 4  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...          1836
#
#    Unnamed: 0.1 Reported Date            Case Number  Crime Type  \
# 0           324      2/9/2016  2016-94027               BURGLARY
# 1           807      4/5/2016  2016-232057                 DRUGS
# 2           808      4/5/2016  2016-232057                 DRUGS
# 3          1091      5/7/2016  2016-311881              MISCHIEF
# 4          2540    10/18/2016  2016-728782              MISCHIEF
#
#             Crime Type Extension                Address    zip  year  \
# 0    BURGLARY RESIDENCE / FORCED  14200 BLOCK 12TH ST N  33613  2016
# 1                DRUGS/NARCOTICS  14200 BLOCK 12TH ST N  33613  2016
# 2             DRUG PARAPHERNALIA  14200 BLOCK 12TH ST N  33613  2016
# 3  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613  2016
# 4  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613  2016
#
#   BlockAddress_y
# 0      N 12TH ST
# 1      N 12TH ST
# 2      N 12TH ST
# 3      N 12TH ST
# 4      N 12TH ST
#
# [5 rows x 23 columns]

# %%
#create data frame from zip code 33613
zip33613_df = merged_df.loc[(merged_df["ZipCode"] == 33613)]
zip33613_df.head()
# Out:
#    Unnamed: 0_x  SEQ_NO               PARCEL_ID  PropertyValue BlockAddress_x  \
# 0         71947   72449  1828010T7000000000290U         118638        12TH ST
# 1         71947   72449  1828010T7000000000290U         118638        12TH ST
# 2         71947   72449  1828010T7000000000290U         118638        12TH ST
# 3         71947   72449  1828010T7000000000290U         118638        12TH ST
# 4         71947   72449  1828010T7000000000290U         118638        12TH ST
#
#    NBRHD_CD     CENSUS_BK    PropAddress   City  ZipCode  ...  Unnamed: 0_y  \
# 0  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...           221
# 1  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...           550
# 2  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...           551
# 3  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...           755
# 4  61400300  120570000000  14202 12TH ST  TAMPA    33613  ...          1836
#
#    Unnamed: 0.1 Reported Date            Case Number  Crime Type  \
# 0           324      2/9/2016  2016-94027               BURGLARY
# 1           807      4/5/2016  2016-232057                 DRUGS
# 2           808      4/5/2016  2016-232057                 DRUGS
# 3          1091      5/7/2016  2016-311881              MISCHIEF
# 4          2540    10/18/2016  2016-728782              MISCHIEF
#
#             Crime Type Extension                Address    zip  year  \
# 0    BURGLARY RESIDENCE / FORCED  14200 BLOCK 12TH ST N  33613  2016
# 1                DRUGS/NARCOTICS  14200 BLOCK 12TH ST N  33613  2016
# 2             DRUG PARAPHERNALIA  14200 BLOCK 12TH ST N  33613  2016
# 3  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613  2016
# 4  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613  2016
#
#   BlockAddress_y
# 0      N 12TH ST
# 1      N 12TH ST
# 2      N 12TH ST
# 3      N 12TH ST
# 4      N 12TH ST
#
# [5 rows x 23 columns]

# %%
merged_df.to_csv("../Resources/test.csv")

# %%
# create new dataframe grouped by neighborhood code
group_nbrhd__33613_df = zip33613_df.groupby('NBRHD_CD')
group_nbrhd__33613_df.head()
# Out:
#          Unnamed: 0_x  SEQ_NO               PARCEL_ID  PropertyValue  \
# 0               71947   72449  1828010T7000000000290U         118638
# 1               71947   72449  1828010T7000000000290U         118638
# 2               71947   72449  1828010T7000000000290U         118638
# 3               71947   72449  1828010T7000000000290U         118638
# 4               71947   72449  1828010T7000000000290U         118638
# ...               ...     ...                     ...            ...
# 1034516         71296   71792  1828010SS000001000010U          53585
# 1034517         71296   71792  1828010SS000001000010U          53585
# 1034518         71296   71792  1828010SS000001000010U          53585
# 1034519         71296   71792  1828010SS000001000010U          53585
# 1034520         71296   71792  1828010SS000001000010U          53585
#
#              BlockAddress_x  NBRHD_CD     CENSUS_BK  \
# 0                   12TH ST  61400300  120570000000
# 1                   12TH ST  61400300  120570000000
# 2                   12TH ST  61400300  120570000000
# 3                   12TH ST  61400300  120570000000
# 4                   12TH ST  61400300  120570000000
# ...                     ...       ...           ...
# 1034516  REUTER STRASSE CIR  81401200  120570000000
# 1034517  REUTER STRASSE CIR  81401200  120570000000
# 1034518  REUTER STRASSE CIR  81401200  120570000000
# 1034519  REUTER STRASSE CIR  81401200  120570000000
# 1034520  REUTER STRASSE CIR  81401200  120570000000
#
#                           PropAddress   City  ZipCode  ...  Unnamed: 0_y  \
# 0                       14202 12TH ST  TAMPA    33613  ...           221
# 1                       14202 12TH ST  TAMPA    33613  ...           550
# 2                       14202 12TH ST  TAMPA    33613  ...           551
# 3                       14202 12TH ST  TAMPA    33613  ...           755
# 4                       14202 12TH ST  TAMPA    33613  ...          1836
# ...                               ...    ...      ...  ...           ...
# 1034516  14418 REUTER STRASSE CIR 101  TAMPA    33613  ...           497
# 1034517  14418 REUTER STRASSE CIR 101  TAMPA    33613  ...           526
# 1034518  14418 REUTER STRASSE CIR 101  TAMPA    33613  ...           610
# 1034519  14418 REUTER STRASSE CIR 101  TAMPA    33613  ...           614
# 1034520  14418 REUTER STRASSE CIR 101  TAMPA    33613  ...          1341
#
#          Unnamed: 0.1 Reported Date            Case Number  Crime Type  \
# 0                 324      2/9/2016  2016-94027               BURGLARY
# 1                 807      4/5/2016  2016-232057                 DRUGS
# 2                 808      4/5/2016  2016-232057                 DRUGS
# 3                1091      5/7/2016  2016-311881              MISCHIEF
# 4                2540    10/18/2016  2016-728782              MISCHIEF
# ...               ...           ...                    ...         ...
# 1034516           732     3/28/2016  2016-210950              BURGLARY
# 1034517           783      4/2/2016  2016-223477              BURGLARY
# 1034518           885     4/13/2016  2016-252297              BURGLARY
# 1034519           893     4/13/2016  2016-252352                 THEFT
# 1034520          1854      8/1/2016  2016-533781              BURGLARY
#
#                   Crime Type Extension                        Address    zip  \
# 0          BURGLARY RESIDENCE / FORCED          14200 BLOCK 12TH ST N  33613
# 1                      DRUGS/NARCOTICS          14200 BLOCK 12TH ST N  33613
# 2                   DRUG PARAPHERNALIA          14200 BLOCK 12TH ST N  33613
# 3        CRIMINAL MISCHIEF MISDEMEANOR          14200 BLOCK 12TH ST N  33613
# 4        CRIMINAL MISCHIEF MISDEMEANOR          14200 BLOCK 12TH ST N  33613
# ...                                ...                            ...    ...
# 1034516           THEFT FROM A VEHICLE  14400 BLOCK REUTER STRASSE CR  33613
# 1034517           THEFT FROM A VEHICLE  14400 BLOCK REUTER STRASSE CR  33613
# 1034518           THEFT FROM A VEHICLE  14400 BLOCK REUTER STRASSE CR  33613
# 1034519        PETIT THEFT - ALL OTHER  14400 BLOCK REUTER STRASSE CR  33613
# 1034520           THEFT FROM A VEHICLE  14400 BLOCK REUTER STRASSE CR  33613
#
#          year      BlockAddress_y
# 0        2016           N 12TH ST
# 1        2016           N 12TH ST
# 2        2016           N 12TH ST
# 3        2016           N 12TH ST
# 4        2016           N 12TH ST
# ...       ...                 ...
# 1034516  2016  REUTER STRASSE CIR
# 1034517  2016  REUTER STRASSE CIR
# 1034518  2016  REUTER STRASSE CIR
# 1034519  2016  REUTER STRASSE CIR
# 1034520  2016  REUTER STRASSE CIR
#
# [174 rows x 23 columns]

# %%
# run calculations calculate average home value and crime counts by neigborhood code

#avg home value by neighborhood code
avg_value = group_nbrhd__33613_df.median()['PropertyValue']
#count of crimes by neighborhood code
total_crime = group_nbrhd__33613_df.count()['Case Number']



#create data frame 
crime_value_plot_33613 = pd.DataFrame({"Avg Prop Value($)": avg_value,
                                "Crime Count": total_crime})
crime_value_plot_33613.head()
# Out:
#           Avg Prop Value($)  Crime Count
# NBRHD_CD
# 21001400           274829.0        14508
# 21100100           215627.5        11680
# 21100200           290751.5         8272
# 21100300           147681.5          540
# 21100600           249340.0        55746

# %%
#crime_value_plot_33613.count()
# drop neighborcodes with avg prop values greater than 1.5 mil
crime_value_plot_33613_df = crime_value_plot_33613.drop(['21101100','21500500','51300100','51500100','51400100',
                                                      '71100100','71400100'])
crime_value_plot_33613_df.head()
# Out:
#           Avg Prop Value($)  Crime Count
# NBRHD_CD
# 21001400           274829.0        14508
# 21100100           215627.5        11680
# 21100200           290751.5         8272
# 21100300           147681.5          540
# 21100600           249340.0        55746

# %%
crime_value_plot_33613_df.count()

# %%
# create bar graph for zip code 33616
crime_value_plot_33613_df.apply(lambda x: x*100/sum(x), axis=1).plot.bar(figsize = (12,10))
plt.title('Property Values and Crime Rates by Neighborhood')
plt.ylabel("Avg Value($) and Crime")
plt.xlabel("Neigborhood Code")
plt.legend(labels=["Avg Prop Values","Crime Count"],loc="best")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#create data frame from zip code 33556
zip33556_df = merged_df.loc[(merged_df["ZipCode"] == 33556)]
zip33556_df.head()
# Out:
#       Unnamed: 0_x  SEQ_NO               PARCEL_ID  PropertyValue  \
# 2368        206550  207815  1928061GB000002000300U         155150
# 2369        206550  207815  1928061GB000002000300U         155150
# 2370        206550  207815  1928061GB000002000300U         155150
# 2371        206550  207815  1928061GB000002000300U         155150
# 2372        206550  207815  1928061GB000002000300U         155150
#
#      BlockAddress_x  NBRHD_CD     CENSUS_BK      PropAddress    City  ZipCode  \
# 2368    E 137TH AVE  61400300  120570000000  701 E 137TH AVE  ODESSA    33556
# 2369    E 137TH AVE  61400300  120570000000  701 E 137TH AVE  ODESSA    33556
# 2370    E 137TH AVE  61400300  120570000000  701 E 137TH AVE  ODESSA    33556
# 2371    E 137TH AVE  61400300  120570000000  701 E 137TH AVE  ODESSA    33556
# 2372    E 137TH AVE  61400300  120570000000  701 E 137TH AVE  ODESSA    33556
#
#       ...  Unnamed: 0_y  Unnamed: 0.1 Reported Date            Case Number  \
# 2368  ...           221           324      2/9/2016  2016-94027
# 2369  ...           550           807      4/5/2016  2016-232057
# 2370  ...           551           808      4/5/2016  2016-232057
# 2371  ...           755          1091      5/7/2016  2016-311881
# 2372  ...          1836          2540    10/18/2016  2016-728782
#
#       Crime Type           Crime Type Extension                Address    zip  \
# 2368    BURGLARY    BURGLARY RESIDENCE / FORCED  14200 BLOCK 12TH ST N  33613
# 2369       DRUGS                DRUGS/NARCOTICS  14200 BLOCK 12TH ST N  33613
# 2370       DRUGS             DRUG PARAPHERNALIA  14200 BLOCK 12TH ST N  33613
# 2371    MISCHIEF  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613
# 2372    MISCHIEF  CRIMINAL MISCHIEF MISDEMEANOR  14200 BLOCK 12TH ST N  33613
#
#       year BlockAddress_y
# 2368  2016      N 12TH ST
# 2369  2016      N 12TH ST
# 2370  2016      N 12TH ST
# 2371  2016      N 12TH ST
# 2372  2016      N 12TH ST
#
# [5 rows x 23 columns]

# %%
# create new dataframe grouped by neighborhood code
group_nbrhd__33556_df = zip33556_df.groupby('NBRHD_CD')
group_nbrhd__33556_df.head()
# Out:
#          Unnamed: 0_x  SEQ_NO               PARCEL_ID  PropertyValue  \
# 2368           206550  207815  1928061GB000002000300U         155150
# 2369           206550  207815  1928061GB000002000300U         155150
# 2370           206550  207815  1928061GB000002000300U         155150
# 2371           206550  207815  1928061GB000002000300U         155150
# 2372           206550  207815  1928061GB000002000300U         155150
# ...               ...     ...                     ...            ...
# 1035462         71341   71838  1828010STA00000000250U          54215
# 1035463         71341   71838  1828010STA00000000250U          54215
# 1035464         71341   71838  1828010STA00000000250U          54215
# 1035465         71341   71838  1828010STA00000000250U          54215
# 1035466         71341   71838  1828010STA00000000250U          54215
#
#              BlockAddress_x  NBRHD_CD     CENSUS_BK  \
# 2368            E 137TH AVE  61400300  120570000000
# 2369            E 137TH AVE  61400300  120570000000
# 2370            E 137TH AVE  61400300  120570000000
# 2371            E 137TH AVE  61400300  120570000000
# 2372            E 137TH AVE  61400300  120570000000
# ...                     ...       ...           ...
# 1035462  REUTER STRASSE CIR  81401200  120570000000
# 1035463  REUTER STRASSE CIR  81401200  120570000000
# 1035464  REUTER STRASSE CIR  81401200  120570000000
# 1035465  REUTER STRASSE CIR  81401200  120570000000
# 1035466  REUTER STRASSE CIR  81401200  120570000000
#
#                           PropAddress    City  ZipCode  ...  Unnamed: 0_y  \
# 2368                  701 E 137TH AVE  ODESSA    33556  ...           221
# 2369                  701 E 137TH AVE  ODESSA    33556  ...           550
# 2370                  701 E 137TH AVE  ODESSA    33556  ...           551
# 2371                  701 E 137TH AVE  ODESSA    33556  ...           755
# 2372                  701 E 137TH AVE  ODESSA    33556  ...          1836
# ...                               ...     ...      ...  ...           ...
# 1035462  14408 REUTER STRASSE CIR 205  ODESSA    33556  ...           497
# 1035463  14408 REUTER STRASSE CIR 205  ODESSA    33556  ...           526
# 1035464  14408 REUTER STRASSE CIR 205  ODESSA    33556  ...           610
# 1035465  14408 REUTER STRASSE CIR 205  ODESSA    33556  ...           614
# 1035466  14408 REUTER STRASSE CIR 205  ODESSA    33556  ...          1341
#
#          Unnamed: 0.1 Reported Date            Case Number  Crime Type  \
# 2368              324      2/9/2016  2016-94027               BURGLARY
# 2369              807      4/5/2016  2016-232057                 DRUGS
# 2370              808      4/5/2016  2016-232057                 DRUGS
# 2371             1091      5/7/2016  2016-311881              MISCHIEF
# 2372             2540    10/18/2016  2016-728782              MISCHIEF
# ...               ...           ...                    ...         ...
# 1035462           732     3/28/2016  2016-210950              BURGLARY
# 1035463           783      4/2/2016  2016-223477              BURGLARY
# 1035464           885     4/13/2016  2016-252297              BURGLARY
# 1035465           893     4/13/2016  2016-252352                 THEFT
# 1035466          1854      8/1/2016  2016-533781              BURGLARY
#
#                   Crime Type Extension                        Address    zip  \
# 2368       BURGLARY RESIDENCE / FORCED          14200 BLOCK 12TH ST N  33613
# 2369                   DRUGS/NARCOTICS          14200 BLOCK 12TH ST N  33613
# 2370                DRUG PARAPHERNALIA          14200 BLOCK 12TH ST N  33613
# 2371     CRIMINAL MISCHIEF MISDEMEANOR          14200 BLOCK 12TH ST N  33613
# 2372     CRIMINAL MISCHIEF MISDEMEANOR          14200 BLOCK 12TH ST N  33613
# ...                                ...                            ...    ...
# 1035462           THEFT FROM A VEHICLE  14400 BLOCK REUTER STRASSE CR  33613
# 1035463           THEFT FROM A VEHICLE  14400 BLOCK REUTER STRASSE CR  33613
# 1035464           THEFT FROM A VEHICLE  14400 BLOCK REUTER STRASSE CR  33613
# 1035465        PETIT THEFT - ALL OTHER  14400 BLOCK REUTER STRASSE CR  33613
# 1035466           THEFT FROM A VEHICLE  14400 BLOCK REUTER STRASSE CR  33613
#
#          year      BlockAddress_y
# 2368     2016           N 12TH ST
# 2369     2016           N 12TH ST
# 2370     2016           N 12TH ST
# 2371     2016           N 12TH ST
# 2372     2016           N 12TH ST
# ...       ...                 ...
# 1035462  2016  REUTER STRASSE CIR
# 1035463  2016  REUTER STRASSE CIR
# 1035464  2016  REUTER STRASSE CIR
# 1035465  2016  REUTER STRASSE CIR
# 1035466  2016  REUTER STRASSE CIR
#
# [143 rows x 23 columns]

# %%
# run calculations calculate average home value and crime counts by neigborhood code

#avg home value by neighborhood code
avg_value = group_nbrhd__33556_df.median()['PropertyValue']
#count of crimes by neighborhood code
total_crime = group_nbrhd__33556_df.count()['Case Number']



#create data frame 
crime_value_plot_33556_df = pd.DataFrame({"Avg Prop Value($)": avg_value,
                                "Crime Count": total_crime})
crime_value_plot_33556_df.head()
# Out:
#           Avg Prop Value($)  Crime Count
# NBRHD_CD
# 21001400           252751.5         1768
# 21100100           234183.0         6278
# 21100200           208358.0         5808
# 21100300           231850.0          990
# 21100600           256288.0         4959

# %%
crime_value_plot_33556_df.count()

# %%
# create bar graph for zip code 33616
crime_value_plot_33556_df.apply(lambda x: x*100/sum(x), axis=1).plot.bar(figsize = (12,10))
plt.title('Property Values and Crime Rates by Neighborhood')
plt.ylabel("Avg Value($) and Crime")
plt.xlabel("Neigborhood Code")
plt.legend(labels=["Avg Prop Values","Crime Count"],loc="best")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
