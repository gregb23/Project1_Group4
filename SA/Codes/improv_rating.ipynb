# %%
#dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#file path
csv_path = "../Resources/improvrating.csv"
improvrating_df = pd.read_csv(csv_path)
improvrating_df.head(10)
# Out:
#    District Number District Name  School Number  \
# 0                1       ALACHUA             81
# 1                1       ALACHUA             82
# 2                1       ALACHUA            955
# 3                1       ALACHUA            991
# 4                1       ALACHUA           1003
# 5                3           BAY            241
# 6                3           BAY            281
# 7                3           BAY            531
# 8                3           BAY            581
# 9                3           BAY            591
#
#                                    School Name  \
# 0                         SIDNEY LANIER CENTER
# 1                           HOSPITAL HOMEBOUND
# 2                    THE EINSTEIN SCHOOL, INC.
# 3                       SIATECH AT GAINESVILLE
# 4  NORTH CENTRAL FLORIDA PUBLIC CHARTER SCHOOL
# 5                            ST. ANDREW SCHOOL
# 6               MARGARET K. LEWIS IN MILLVILLE
# 7                 NEW HORIZONS LEARNING CENTER
# ...

# %%
#identify columns names used in the data
improvrating_df.columns
# Out:
# Index(['District Number', 'District Name', 'School Number', 'School Name',
#        'English Language Arts Learning Gains', 'Mathematics Learning Gains',
#        'Total Points Earned', 'Total Components',
#        'Percent of Total Possible Points', 'Percent Tested',
#        'School Improvement Rating 2019', 'Improvement Rating 2018',
#        'Improvement Rating 2017', 'Improvement Rating 2016',
#        'Improvement Rating 2014', 'Improvement Rating 2013',
#        'Improvement Rating 2012', 'Improvement Rating 2011',
#        'Improvement Rating 2010', 'Improvement Rating 2009',
#        'Improvement Rating 2008', 'Charter School',
#        'Alternative/ESE Center School', 'School Type', 'Title I',
#        'Percent of Minority Students',
#        'Percent of Economically Disadvantaged Students',
#        'Was the aggregate rule used?'],
#       dtype='object')

# %%
#remove some columns from the data 
improvrating_reduced_df = improvrating_df.loc[:, ['District Number', 'District Name', 'School Number', 'School Name',
       'English Language Arts Learning Gains', 'Mathematics Learning Gains',
       'Total Points Earned', 'Total Components',
       'Percent of Total Possible Points', 'Percent Tested',
       'School Improvement Rating 2019', 'Improvement Rating 2018',
       'Improvement Rating 2017', 'Improvement Rating 2016', 'School Type',
       'Percent of Minority Students',
       'Percent of Economically Disadvantaged Students']]
improvrating_reduced_df.head(10)
# Out:
#    District Number District Name  School Number  \
# 0                1       ALACHUA             81
# 1                1       ALACHUA             82
# 2                1       ALACHUA            955
# 3                1       ALACHUA            991
# 4                1       ALACHUA           1003
# 5                3           BAY            241
# 6                3           BAY            281
# 7                3           BAY            531
# 8                3           BAY            581
# 9                3           BAY            591
#
#                                    School Name  \
# 0                         SIDNEY LANIER CENTER
# 1                           HOSPITAL HOMEBOUND
# 2                    THE EINSTEIN SCHOOL, INC.
# 3                       SIATECH AT GAINESVILLE
# 4  NORTH CENTRAL FLORIDA PUBLIC CHARTER SCHOOL
# 5                            ST. ANDREW SCHOOL
# 6               MARGARET K. LEWIS IN MILLVILLE
# 7                 NEW HORIZONS LEARNING CENTER
# ...

# %%
#columns to use in the table below 
columns = ['District Name', 'School Number', 'School Name',
       'English Language Arts Learning Gains', 'Mathematics Learning Gains',
       'Total Points Earned',
       'Percent of Total Possible Points', 'Percent Tested',
       'School Improvement Rating 2019', 'Improvement Rating 2018',
       'Improvement Rating 2017', 'Improvement Rating 2016',
       'Percent of Minority Students',
       'Percent of Economically Disadvantaged Students'
]
#create a new DF for non Traffic related crimes
hillsschools_df = improvrating_reduced_df.loc[improvrating_reduced_df["District Name"] == "HILLSBOROUGH", columns]
hillsschools_df.head(10)
# Out:
#     District Name  School Number                                 School Name  \
# 96   HILLSBOROUGH             63                   CARVER EXCEPTIONAL CENTER
# 97   HILLSBOROUGH            363                        WATERS CAREER CENTER
# 98   HILLSBOROUGH            371                       SIMMONS CAREER CENTER
# 99   HILLSBOROUGH           1202            WILLIS PETERS EXCEPTIONAL CENTER
# 100  HILLSBOROUGH           2541  LOPEZ EXCEPTIONAL STUDENT EDUCATION CENTER
# 101  HILLSBOROUGH           2972                   MENDEZ EXCEPTIONAL CENTER
# 102  HILLSBOROUGH           3782                    LAVOY EXCEPTIONAL CENTER
# 103  HILLSBOROUGH           4002                  SIMMONS EXCEPTIONAL CENTER
# 104  HILLSBOROUGH           4154                  SOUTH COUNTY CAREER CENTER
# 105  HILLSBOROUGH           4155                BOWERS-WHITLEY CAREER CENTER
#
#      English Language Arts Learning Gains  Mathematics Learning Gains  \
# ...
